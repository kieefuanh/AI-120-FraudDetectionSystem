# %%
'''importing the required libraries'''
import pandas as pd
import copy
import numpy as np
from numpy import argmax
from matplotlib import pyplot

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
import tensorflow as tf

from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score
from sklearn.metrics import precision_recall_curve, auc, roc_auc_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ## Prepare original dataset

# %%
# from collections import Counter
# counter = Counter(y_test3.index)
# more_than_one = [id for id, count in counter.items() if count >= 2]
# print(len(more_than_one))

# %%
'''Importing the dataset and checking its properties '''
ori_data =  pd.read_csv("data/creditcard.csv")
print(ori_data.Class.value_counts())
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
'''removing the unwanted features'''
ori_data.drop('Time', axis=1, inplace=True)

# %%
ori_data.drop_duplicates(inplace=True)

# %%
ori_data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# 0  0.128539 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.167170  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.327642 -0.139097 -0.055353 -0.059752  378.66      0
# 3  0.647376 -0.221929  0.062723  0.061458  123.50      0
# 4 -0.206010  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 30 columns]

# %%
label_cols = [ i for i in ori_data.columns if 'Class' in i ]
data_cols = [ i for i in ori_data.columns if i not in label_cols ]

print('Dataset columns: {}'.format(", ".join(data_cols)))
# Out:
# Dataset columns: V1, V2, V3, V4, V5, V6, V7, V8, V9, V10, V11, V12, V13, V14, V15, V16, V17, V18, V19, V20, V21, V22, V23, V24, V25, V26, V27, V28, Amount

# %%
x_temp = ori_data.groupby(data_cols).size().reset_index(name='count')
x_temp['count'].value_counts()
# Out:
# 1    275663
# Name: count, dtype: int64

# %% [markdown]
# ## Prepare synthetic data

# %%
synth_data = [
            ('GaussianCopula140000', 'data/1GaussianCopula140000.csv'),
                ('Synthpop140000', 'data/mysyn.csv'),
          ('CTGAN140000', 'data/1CTGAN140000.csv'),
          ('CopulaGAN140000', 'data/1CopulaGAN140000.csv'),
          ('TVAE140000', 'data/1TVAE140000.csv'),
           ]

# %% [markdown]
# ## Models

# %%
#scaling
def standard_scaler(X_train, X_test):
    sc = StandardScaler()
    x_train_scaled = sc.fit_transform(X_train)
    x_test_scaled = sc.transform(X_test)
    return x_train_scaled, x_test_scaled

# %%
def evaluate(y_prob, y_label):
    y_pred = np.where(y_prob>0.5, 1,0)
    acc = accuracy_score(y_label,y_pred)*100
    print('Accuracy:',round(acc,2))
    
    ''' Generating the Confusion matrix and Classification report'''
    print('Confusion matrix', '\n', confusion_matrix(y_label, y_pred), '\n')
    print('Classification report', '\n', classification_report(y_label, y_pred), '\n')
    
    f1s = f1_score(y_label, y_pred, average='macro')
    f1s = round(f1s, 2)
    
    print(f"F1_Score: {f1s}")
    
    # calculate pr-curve
    precision, recall, thresholds = precision_recall_curve(y_label, y_prob)
    
#     # # plot the roc curve for the model
#     no_skill = len(y_label[y_label==1]) / len(y_label)
#     pyplot.plot([0,1], [no_skill,no_skill], linestyle='--', label='No Skill')
#     pyplot.plot(recall, precision, marker='.', label='PR Curve')
#     # axis labels
#     pyplot.xlabel('Recall')
#     pyplot.ylabel('Precision')
#     pyplot.legend()
#     # show the plot
#     pyplot.show()
    
    # convert to f score
    fscore = (2 * precision * recall) / (precision + recall)
    # locate the index of the largest f score
    ix = argmax(fscore)
    print('Best Threshold=%f, F-Score=%.3f' % (thresholds[ix], fscore[ix]))

    pr_auc = auc(recall, precision)
    print('PR AUC= %.3f'% pr_auc)

    y_pred = np.where(y_prob>thresholds[ix], 1,0)
    print('Confusion matrix', '\n',confusion_matrix(y_label, y_pred))
    print('Classification report', '\n', classification_report(y_label, y_pred), '\n')
    return f1s

# %% [markdown]
# ### Fully Connected no bias - class weights

# %%
WEIGHTS_PATH = 'initialFLC/initial_weights'
EPOCH = 10
BATCH_SIZE = 16
LOOP = 10

# %%
'''Fully Connected'''
''' Initializing the model '''

fcl = Sequential()

''' Adding the input layer and the first hidden layer '''

fcl.add(Dense(input_dim=29, units = 6, kernel_initializer='random_uniform', activation = 'relu'))

''' Adding the second hidden layer '''

fcl.add(Dense(units = 6, kernel_initializer='random_uniform', activation = 'relu'))

''' Adding the output layer '''

fcl.add(Dense(units = 1, kernel_initializer='random_uniform', activation = 'sigmoid'
               #,bias_initializer=output_bias
               ))
fcl.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
fcl.save_weights(WEIGHTS_PATH)

# %%
def train(batch_size, epoch, X, y):
    #load initial weights
    fcl.load_weights(WEIGHTS_PATH)
    
    # train
    fcl.fit(X, y, 
            #class_weight=class_weight,
            batch_size = batch_size, epochs = epoch
            #, verbose=0
            )

    #model.save_weights('model/model_weights{}'.format(name))

# %% [markdown]
# ### Random Forest Classifier

# %%
RFC_PARAMS = dict(
    n_estimators=300, max_depth=8, max_leaf_nodes=2**6, class_weight="balanced_subsample"
)

# %% [markdown]
# ## Train

# %%
#input: dataset
#return: fcl and rfc f1 score 
def train_evaluate(X_train, y_train, X_test, y_test):
    '''Fully Connected Layer'''
    print("Fully connected layer \n")
    train(BATCH_SIZE, EPOCH, X_train, y_train)
    
    fcl_y_prob = fcl.predict(X_test)
    fcl_f1 = evaluate(fcl_y_prob, y_test)
    
    print("Random Forest Classifier \n")
    rfc = RandomForestClassifier(**RFC_PARAMS)
    rfc.fit(X_train, y_train)
    
    rfc_y_prob = rfc.predict_proba(X_test)[:,1]
    rfc_f1 = evaluate(rfc_y_prob, y_test)
    
    return fcl_f1, rfc_f1

# %% [markdown]
# ## 1.Train Real - Test Real
#     Train 80% của 20k nhãn 0, 80% nhãn 1 của 492
#     Test 20% còn lại.

# %%
zero_label = 20000
sampled_data = pd.concat([ori_data[ori_data.Class == 1], ori_data[ori_data.Class==0].sample(zero_label)], axis=0)

sss = StratifiedShuffleSplit(test_size=0.2, random_state=42)
train_idx, test_idx = next(sss.split(sampled_data, sampled_data["Class"]))
X_train1, X_test1 = sampled_data.iloc[train_idx][data_cols], sampled_data.iloc[test_idx][data_cols],
y_train1, y_test1 =sampled_data.iloc[train_idx]["Class"], sampled_data.iloc[test_idx]["Class"]

# %%
y_test1.value_counts()

# %%
X_train1, X_test1 = standard_scaler(X_train1, X_test1)

# %%
rfc_f1_list = []
fcl_f1_list = []
for i in range (0,LOOP):
    fcl_f1, rfc_f1 = train_evaluate(X_train1, y_train1, X_test1, y_test1)
    fcl_f1_list.append(fcl_f1)
    rfc_f1_list.append(rfc_f1)

# %%
print(f'> F1 Score FCL: {np.mean(fcl_f1_list)} (Độ lệch +- {np.std(fcl_f1_list)})')
print(f'> F1 Score RFC: {np.mean(rfc_f1_list)} (Độ lệch +- {np.std(rfc_f1_list)})')

# %% [markdown]
# ## 2.Train Synthetic - Test Real
#     Train 112k
#     Test 9840 - 492

# %%
train_size0 = 112000
test_size1 = 492

#get test set with 492 real 1 and 492*20 0
sample_data2 = pd.concat([ori_data[ori_data.Class == 1], ori_data[ori_data.Class==0].sample(test_size1*20)], axis=0)
#sample_data2 = pd.concat([ori_data[ori_data.Class == 1], ori_data[ori_data.Class==0].sample(160000)], axis=0)
X_test2 = sample_data2[data_cols]
y_test2 = sample_data2["Class"]
y_test2 = y_test2.to_numpy()

#get the rest of the dataset (drop test)
sample_data_left2 = ori_data.drop(list(sample_data2.index))

# %%
sample_data_left2
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V21       V22  \
# 0       0.239599  0.098698  0.363787  0.090794  ... -0.018307  0.277838
# 1      -0.078803  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672
# 2       0.791461  0.247676 -1.514654  0.207643  ...  0.247998  0.771679
# 3       0.237609  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274
# 4       0.592941 -0.270533  0.817739  0.753074  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -4.918215  7.305334  1.914428  4.356170  ...  0.213454  0.111864
# 284803  0.024330  0.294869  0.584800 -0.975926  ...  0.214205  0.924384
# 284804 -0.296827  0.708417  0.432454 -0.484782  ...  0.232045  0.578229
# 284805 -0.686180  0.679145  0.392087 -0.399126  ...  0.265245  0.800049
# 284806  1.577006 -0.414650  0.486180 -0.915427  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [265350 rows x 30 columns]

# %%
train_size1 = copy.deepcopy(train_size0)
for name, data_path in synth_data:
    print("------------------------------------------", name)
    rfc_f1_list = []
    fcl_f1_list = []
    
    #add synthetic data into train dataset
    gen_data = pd.read_csv(data_path)[data_cols]
    gen_data["Class"] = np.ones(gen_data.shape[0], dtype = int)
    data2 = pd.concat([gen_data.sample(train_size1), 
                       sample_data_left2.sample(train_size0)]).sample(train_size1+train_size0)    
    data2 = data2.reset_index(drop = True)
    
    check_dup = data2.append(sample_data2)
    print(check_dup.duplicated().any())
    
    X_train2 = data2[data_cols]
    y_train2 = data2["Class"]
    
    train_data2, test_data2 = standard_scaler(X_train2, X_test2)
    
    y_train2 = y_train2.to_numpy()
    
    for i in range(0,10):
        fcl_f1, rfc_f1 = train_evaluate(train_data2, y_train2, test_data2, y_test2)
        fcl_f1_list.append(fcl_f1)
        rfc_f1_list.append(rfc_f1)
    print(f'> F1 Score FCL: {np.mean(fcl_f1_list)} (Độ lệch +- {np.std(fcl_f1_list)})')
    print(f'> F1 Score RFC: {np.mean(rfc_f1_list)} (Độ lệch +- {np.std(rfc_f1_list)})')
# Out:
# ------------------------------------------ Synthpop140000
# False
# Fully connected layer
#
# Epoch 1/10
# 14000/14000 [==============================] - 31s 2ms/step - loss: 0.1355 - accuracy: 0.9557
# Epoch 2/10
# 14000/14000 [==============================] - 31s 2ms/step - loss: 0.0844 - accuracy: 0.9706
# Epoch 3/10
# 14000/14000 [==============================] - 27s 2ms/step - loss: 0.0693 - accuracy: 0.9765
# Epoch 4/10
# 14000/14000 [==============================] - 28s 2ms/step - loss: 0.0575 - accuracy: 0.9812
# Epoch 5/10
# 14000/14000 [==============================] - 26s 2ms/step - loss: 0.0494 - accuracy: 0.9837
# Epoch 6/10
# 14000/14000 [==============================] - 28s 2ms/step - loss: 0.0430 - accuracy: 0.9863
# Epoch 7/10
# 14000/14000 [==============================] - 29s 2ms/step - loss: 0.0397 - accuracy: 0.9875
# Epoch 8/10
# 14000/14000 [==============================] - 31s 2ms/step - loss: 0.0364 - accuracy: 0.9889
# Epoch 9/10
# 14000/14000 [==============================] - 34s 2ms/step - loss: 0.0348 - accuracy: 0.9896
# Epoch 10/10
# 14000/14000 [==============================] - 40s 3ms/step - loss: 0.0331 - accuracy: 0.9900
# Accuracy: 98.76
# Confusion matrix
#  [[9776   64]
#  [  64  409]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      9840
#            1       0.86      0.86      0.86       473
#
#     accuracy                           0.99     10313
#    macro avg       0.93      0.93      0.93     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# F1_Score: 0.93
# Best Threshold=0.732988, F-Score=0.898
# PR AUC= 0.919
# Confusion matrix
#  [[9818   22]
#  [  71  402]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      9840
#            1       0.95      0.85      0.90       473
#
#     accuracy                           0.99     10313
#    macro avg       0.97      0.92      0.95     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# Random Forest Classifier
#
# Accuracy: 98.97
# Confusion matrix
#  [[9780   60]
#  [  46  427]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      9840
#            1       0.88      0.90      0.89       473
#
#     accuracy                           0.99     10313
#    macro avg       0.94      0.95      0.94     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# F1_Score: 0.94
# Best Threshold=0.811303, F-Score=0.914
# PR AUC= 0.939
# Confusion matrix
#  [[9831    9]
#  [  68  405]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      9840
#            1       0.98      0.86      0.91       473
#
#     accuracy                           0.99     10313
#    macro avg       0.99      0.93      0.95     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# Fully connected layer
#
# Epoch 1/10
# 14000/14000 [==============================] - 34s 2ms/step - loss: 0.1670 - accuracy: 0.9409
# Epoch 2/10
# 14000/14000 [==============================] - 34s 2ms/step - loss: 0.0929 - accuracy: 0.9678
# Epoch 3/10
# 14000/14000 [==============================] - 27s 2ms/step - loss: 0.0660 - accuracy: 0.9787
# Epoch 4/10
# 14000/14000 [==============================] - 33s 2ms/step - loss: 0.0526 - accuracy: 0.9838
# Epoch 5/10
# 14000/14000 [==============================] - 26s 2ms/step - loss: 0.0448 - accuracy: 0.9866
# Epoch 6/10
# 14000/14000 [==============================] - 25s 2ms/step - loss: 0.0403 - accuracy: 0.9878
# Epoch 7/10
# 14000/14000 [==============================] - 28s 2ms/step - loss: 0.0375 - accuracy: 0.9884
# Epoch 8/10
# 14000/14000 [==============================] - 27s 2ms/step - loss: 0.0349 - accuracy: 0.9894
# Epoch 9/10
# 14000/14000 [==============================] - 26s 2ms/step - loss: 0.0326 - accuracy: 0.9901
# Epoch 10/10
# 14000/14000 [==============================] - 27s 2ms/step - loss: 0.0311 - accuracy: 0.9906
# Accuracy: 98.89
# Confusion matrix
#  [[9792   48]
#  [  66  407]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      9840
#            1       0.89      0.86      0.88       473
#
#     accuracy                           0.99     10313
#    macro avg       0.94      0.93      0.94     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# F1_Score: 0.94
# Best Threshold=0.774854, F-Score=0.896
# PR AUC= 0.909
# Confusion matrix
#  [[9826   14]
#  [  79  394]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      9840
#            1       0.97      0.83      0.89       473
#
#     accuracy                           0.99     10313
#    macro avg       0.98      0.92      0.94     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# Random Forest Classifier
#
# Accuracy: 98.97
# Confusion matrix
#  [[9780   60]
#  [  46  427]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      9840
#            1       0.88      0.90      0.89       473
#
#     accuracy                           0.99     10313
#    macro avg       0.94      0.95      0.94     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# F1_Score: 0.94
# Best Threshold=0.812605, F-Score=0.914
# PR AUC= 0.939
# Confusion matrix
#  [[9831    9]
#  [  68  405]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      9840
#            1       0.98      0.86      0.91       473
#
#     accuracy                           0.99     10313
#    macro avg       0.99      0.93      0.95     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# Fully connected layer
#
# Epoch 1/10
# 14000/14000 [==============================] - 29s 2ms/step - loss: 0.1622 - accuracy: 0.9384
# Epoch 2/10
# 14000/14000 [==============================] - 32s 2ms/step - loss: 0.0896 - accuracy: 0.9678
# Epoch 3/10
# 14000/14000 [==============================] - 31s 2ms/step - loss: 0.0750 - accuracy: 0.9741
# Epoch 4/10
# 14000/14000 [==============================] - 33s 2ms/step - loss: 0.0633 - accuracy: 0.9789
# Epoch 5/10
# 14000/14000 [==============================] - 28s 2ms/step - loss: 0.0577 - accuracy: 0.9808
# Epoch 6/10
# 14000/14000 [==============================] - 29s 2ms/step - loss: 0.0532 - accuracy: 0.9822
# Epoch 7/10
# 14000/14000 [==============================] - 31s 2ms/step - loss: 0.0494 - accuracy: 0.9838
# Epoch 8/10
# 14000/14000 [==============================] - 34s 2ms/step - loss: 0.0461 - accuracy: 0.9846
# Epoch 9/10
# 14000/14000 [==============================] - 30s 2ms/step - loss: 0.0441 - accuracy: 0.9857
# Epoch 10/10
# 14000/14000 [==============================] - 33s 2ms/step - loss: 0.0420 - accuracy: 0.9862
# Accuracy: 98.39
# Confusion matrix
#  [[9734  106]
#  [  60  413]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      9840
#            1       0.80      0.87      0.83       473
#
#     accuracy                           0.98     10313
#    macro avg       0.89      0.93      0.91     10313
# weighted avg       0.98      0.98      0.98     10313
#
#
# F1_Score: 0.91
# Best Threshold=0.937337, F-Score=0.885
# PR AUC= 0.912
# Confusion matrix
#  [[9827   13]
#  [  88  385]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      9840
#            1       0.97      0.81      0.88       473
#
#     accuracy                           0.99     10313
#    macro avg       0.98      0.91      0.94     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# Random Forest Classifier
#
# Accuracy: 98.97
# Confusion matrix
#  [[9780   60]
#  [  46  427]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      9840
#            1       0.88      0.90      0.89       473
#
#     accuracy                           0.99     10313
#    macro avg       0.94      0.95      0.94     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# F1_Score: 0.94
# Best Threshold=0.851895, F-Score=0.914
# PR AUC= 0.939
# Confusion matrix
#  [[9834    6]
#  [  71  402]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      9840
#            1       0.99      0.85      0.91       473
#
#     accuracy                           0.99     10313
#    macro avg       0.99      0.92      0.95     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# Fully connected layer
# Epoch 1/10
# 14000/14000 [==============================] - 33s 2ms/step - loss: 0.1696 - accuracy: 0.9357
# Epoch 2/10
# 14000/14000 [==============================] - 29s 2ms/step - loss: 0.0927 - accuracy: 0.9682
# Epoch 3/10
# 14000/14000 [==============================] - 34s 2ms/step - loss: 0.0751 - accuracy: 0.9751
# Epoch 4/10
# 14000/14000 [==============================] - 37s 3ms/step - loss: 0.0679 - accuracy: 0.9777
# Epoch 5/10
# 14000/14000 [==============================] - 33s 2ms/step - loss: 0.0598 - accuracy: 0.9803
# Epoch 6/10
# 14000/14000 [==============================] - 35s 2ms/step - loss: 0.0551 - accuracy: 0.9818 0s - loss: 0
# Epoch 7/10
# 14000/14000 [==============================] - 32s 2ms/step - loss: 0.0527 - accuracy: 0.9825
# Epoch 8/10
# 14000/14000 [==============================] - 34s 2ms/step - loss: 0.0510 - accuracy: 0.9833
# Epoch 9/10
# 14000/14000 [==============================] - 32s 2ms/step - loss: 0.0499 - accuracy: 0.9835
# Epoch 10/10
# 14000/14000 [==============================] - 46s 3ms/step - loss: 0.0479 - accuracy: 0.9840
# Accuracy: 98.57
# Confusion matrix
#  [[9743   97]
#  [  50  423]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      9840
#            1       0.81      0.89      0.85       473
#
#     accuracy                           0.99     10313
#    macro avg       0.90      0.94      0.92     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# F1_Score: 0.92
# Best Threshold=0.772006, F-Score=0.885
# PR AUC= 0.921
# Confusion matrix
#  [[9800   40]
#  [  67  406]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      9840
#            1       0.91      0.86      0.88       473
#
#     accuracy                           0.99     10313
#    macro avg       0.95      0.93      0.94     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# Random Forest Classifier
#
# Accuracy: 98.97
# Confusion matrix
#  [[9781   59]
#  [  47  426]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      9840
#            1       0.88      0.90      0.89       473
#
#     accuracy                           0.99     10313
#    macro avg       0.94      0.95      0.94     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# F1_Score: 0.94
# Best Threshold=0.855239, F-Score=0.914
# PR AUC= 0.940
# Confusion matrix
#  [[9834    6]
#  [  71  402]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      9840
#            1       0.99      0.85      0.91       473
#
#     accuracy                           0.99     10313
#    macro avg       0.99      0.92      0.95     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# Fully connected layer
#
# Epoch 1/10
# 14000/14000 [==============================] - 29s 2ms/step - loss: 0.1781 - accuracy: 0.9334
# Epoch 2/10
# 14000/14000 [==============================] - 28s 2ms/step - loss: 0.0936 - accuracy: 0.9669
# Epoch 3/10
# 14000/14000 [==============================] - 27s 2ms/step - loss: 0.0738 - accuracy: 0.9757
# Epoch 4/10
# 14000/14000 [==============================] - 28s 2ms/step - loss: 0.0583 - accuracy: 0.9819
# Epoch 5/10
# 14000/14000 [==============================] - 28s 2ms/step - loss: 0.0506 - accuracy: 0.9841
# Epoch 6/10
# 14000/14000 [==============================] - 29s 2ms/step - loss: 0.0459 - accuracy: 0.9855
# Epoch 7/10
# 14000/14000 [==============================] - 27s 2ms/step - loss: 0.0426 - accuracy: 0.9868
# Epoch 8/10
# 14000/14000 [==============================] - 28s 2ms/step - loss: 0.0399 - accuracy: 0.9878 0s - loss:
# Epoch 9/10
# 14000/14000 [==============================] - 27s 2ms/step - loss: 0.0377 - accuracy: 0.9883 0s
# Epoch 10/10
# 14000/14000 [==============================] - 28s 2ms/step - loss: 0.0355 - accuracy: 0.9891
# Accuracy: 98.68
# Confusion matrix
#  [[9762   78]
#  [  58  415]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      9840
#            1       0.84      0.88      0.86       473
#
#     accuracy                           0.99     10313
#    macro avg       0.92      0.93      0.93     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# F1_Score: 0.93
# Best Threshold=0.849213, F-Score=0.895
# PR AUC= 0.918
# Confusion matrix
#  [[9824   16]
#  [  78  395]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      9840
#            1       0.96      0.84      0.89       473
#
#     accuracy                           0.99     10313
#    macro avg       0.98      0.92      0.94     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# Random Forest Classifier
#
# Accuracy: 98.97
# Confusion matrix
#  [[9779   61]
#  [  45  428]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      9840
#            1       0.88      0.90      0.89       473
#
#     accuracy                           0.99     10313
#    macro avg       0.94      0.95      0.94     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# F1_Score: 0.94
# Best Threshold=0.841286, F-Score=0.915
# PR AUC= 0.940
# Confusion matrix
#  [[9833    7]
#  [  69  404]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      9840
#            1       0.98      0.85      0.91       473
#
#     accuracy                           0.99     10313
#    macro avg       0.99      0.93      0.96     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# Fully connected layer
#
# Epoch 1/10
# 14000/14000 [==============================] - 36s 3ms/step - loss: 0.1684 - accuracy: 0.9360
# Epoch 2/10
# 14000/14000 [==============================] - 32s 2ms/step - loss: 0.0833 - accuracy: 0.9712
# Epoch 3/10
# 14000/14000 [==============================] - 30s 2ms/step - loss: 0.0698 - accuracy: 0.9769
# Epoch 4/10
# 14000/14000 [==============================] - 30s 2ms/step - loss: 0.0605 - accuracy: 0.9807
# Epoch 5/10
# 14000/14000 [==============================] - 30s 2ms/step - loss: 0.0509 - accuracy: 0.9836
# Epoch 6/10
# 14000/14000 [==============================] - 30s 2ms/step - loss: 0.0450 - accuracy: 0.9857
# Epoch 7/10
# 14000/14000 [==============================] - 29s 2ms/step - loss: 0.0411 - accuracy: 0.9871
# Epoch 8/10
# 14000/14000 [==============================] - 27s 2ms/step - loss: 0.0390 - accuracy: 0.9879
# Epoch 9/10
# 14000/14000 [==============================] - 26s 2ms/step - loss: 0.0373 - accuracy: 0.9883
# Epoch 10/10
# 14000/14000 [==============================] - 29s 2ms/step - loss: 0.0368 - accuracy: 0.9887
# Accuracy: 98.69
# Confusion matrix
#  [[9768   72]
#  [  63  410]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      9840
#            1       0.85      0.87      0.86       473
#
#     accuracy                           0.99     10313
#    macro avg       0.92      0.93      0.93     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# F1_Score: 0.93
# Best Threshold=0.829820, F-Score=0.896
# PR AUC= 0.921
# Confusion matrix
#  [[9821   19]
#  [  75  398]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      9840
#            1       0.95      0.84      0.89       473
#
#     accuracy                           0.99     10313
#    macro avg       0.97      0.92      0.94     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# Random Forest Classifier
#
# Accuracy: 98.95
# Confusion matrix
#  [[9777   63]
#  [  45  428]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      9840
#            1       0.87      0.90      0.89       473
#
#     accuracy                           0.99     10313
#    macro avg       0.93      0.95      0.94     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# F1_Score: 0.94
# Best Threshold=0.824964, F-Score=0.914
# PR AUC= 0.940
# Confusion matrix
#  [[9831    9]
#  [  68  405]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      9840
#            1       0.98      0.86      0.91       473
#
#     accuracy                           0.99     10313
#    macro avg       0.99      0.93      0.95     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# Fully connected layer
# Epoch 1/10
# 14000/14000 [==============================] - 25s 2ms/step - loss: 0.1628 - accuracy: 0.9409
# Epoch 2/10
# 14000/14000 [==============================] - 29s 2ms/step - loss: 0.0903 - accuracy: 0.9684
# Epoch 3/10
# 14000/14000 [==============================] - 29s 2ms/step - loss: 0.0642 - accuracy: 0.9784
# Epoch 4/10
# 14000/14000 [==============================] - 34s 2ms/step - loss: 0.0433 - accuracy: 0.9862
# Epoch 5/10
# 14000/14000 [==============================] - 28s 2ms/step - loss: 0.0345 - accuracy: 0.9892
# Epoch 6/10
# 14000/14000 [==============================] - 27s 2ms/step - loss: 0.0313 - accuracy: 0.9905
# Epoch 7/10
# 14000/14000 [==============================] - 29s 2ms/step - loss: 0.0297 - accuracy: 0.9909
# Epoch 8/10
# 14000/14000 [==============================] - 32s 2ms/step - loss: 0.0280 - accuracy: 0.9915 1s - los - ETA: 0s - l
# Epoch 9/10
# 14000/14000 [==============================] - 43s 3ms/step - loss: 0.0275 - accuracy: 0.9917
# Epoch 10/10
# 14000/14000 [==============================] - 29s 2ms/step - loss: 0.0266 - accuracy: 0.9919
# Accuracy: 98.58
# Confusion matrix
#  [[9767   73]
#  [  73  400]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      9840
#            1       0.85      0.85      0.85       473
#
#     accuracy                           0.99     10313
#    macro avg       0.92      0.92      0.92     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# F1_Score: 0.92
# Best Threshold=0.953364, F-Score=0.880
# PR AUC= 0.900
# Confusion matrix
#  [[9829   11]
#  [  94  379]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      9840
#            1       0.97      0.80      0.88       473
#
#     accuracy                           0.99     10313
#    macro avg       0.98      0.90      0.94     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# Random Forest Classifier
#
# Accuracy: 98.96
# Confusion matrix
#  [[9779   61]
#  [  46  427]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      9840
#            1       0.88      0.90      0.89       473
#
#     accuracy                           0.99     10313
#    macro avg       0.94      0.95      0.94     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# F1_Score: 0.94
# Best Threshold=0.819276, F-Score=0.913
# PR AUC= 0.939
# Confusion matrix
#  [[9830   10]
#  [  68  405]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      9840
#            1       0.98      0.86      0.91       473
#
#     accuracy                           0.99     10313
#    macro avg       0.98      0.93      0.95     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# Fully connected layer
#
# Epoch 1/10
# 14000/14000 [==============================] - 30s 2ms/step - loss: 0.1580 - accuracy: 0.9431
# Epoch 2/10
# 14000/14000 [==============================] - 36s 3ms/step - loss: 0.0806 - accuracy: 0.9729
# Epoch 3/10
# 14000/14000 [==============================] - 38s 3ms/step - loss: 0.0698 - accuracy: 0.9777
# Epoch 4/10
# 14000/14000 [==============================] - 26s 2ms/step - loss: 0.0631 - accuracy: 0.9803
# Epoch 5/10
# 14000/14000 [==============================] - 24s 2ms/step - loss: 0.0579 - accuracy: 0.9823
# Epoch 6/10
# 14000/14000 [==============================] - 25s 2ms/step - loss: 0.0543 - accuracy: 0.9831
# Epoch 7/10
# 14000/14000 [==============================] - 26s 2ms/step - loss: 0.0511 - accuracy: 0.9845
# Epoch 8/10
# 14000/14000 [==============================] - 28s 2ms/step - loss: 0.0480 - accuracy: 0.9855
# Epoch 9/10
# 14000/14000 [==============================] - 30s 2ms/step - loss: 0.0438 - accuracy: 0.9870
# Epoch 10/10
# 14000/14000 [==============================] - 29s 2ms/step - loss: 0.0405 - accuracy: 0.9882
# Accuracy: 98.64
# Confusion matrix
#  [[9758   82]
#  [  58  415]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      9840
#            1       0.84      0.88      0.86       473
#
#     accuracy                           0.99     10313
#    macro avg       0.91      0.93      0.92     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# F1_Score: 0.92
# Best Threshold=0.691350, F-Score=0.882
# PR AUC= 0.917
# Confusion matrix
#  [[9798   42]
#  [  68  405]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      9840
#            1       0.91      0.86      0.88       473
#
#     accuracy                           0.99     10313
#    macro avg       0.95      0.93      0.94     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# Random Forest Classifier
#
# Accuracy: 98.98
# Confusion matrix
#  [[9780   60]
#  [  45  428]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      9840
#            1       0.88      0.90      0.89       473
#
#     accuracy                           0.99     10313
#    macro avg       0.94      0.95      0.94     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# F1_Score: 0.94
# Best Threshold=0.831902, F-Score=0.914
# PR AUC= 0.940
# Confusion matrix
#  [[9832    8]
#  [  69  404]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      9840
#            1       0.98      0.85      0.91       473
#
#     accuracy                           0.99     10313
#    macro avg       0.99      0.93      0.95     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# Fully connected layer
#
# Epoch 1/10
# 14000/14000 [==============================] - 24s 2ms/step - loss: 0.1675 - accuracy: 0.9350
# Epoch 2/10
# 14000/14000 [==============================] - 27s 2ms/step - loss: 0.0833 - accuracy: 0.9711
# Epoch 3/10
# 14000/14000 [==============================] - 27s 2ms/step - loss: 0.0627 - accuracy: 0.9794
# Epoch 4/10
# 14000/14000 [==============================] - 28s 2ms/step - loss: 0.0533 - accuracy: 0.9830
# Epoch 5/10
# 14000/14000 [==============================] - 26s 2ms/step - loss: 0.0478 - accuracy: 0.9847
# Epoch 6/10
# 14000/14000 [==============================] - 25s 2ms/step - loss: 0.0444 - accuracy: 0.9862
# Epoch 7/10
# 14000/14000 [==============================] - 29s 2ms/step - loss: 0.0423 - accuracy: 0.9867
# Epoch 8/10
# 14000/14000 [==============================] - 25s 2ms/step - loss: 0.0401 - accuracy: 0.9872
# Epoch 9/10
# 14000/14000 [==============================] - 27s 2ms/step - loss: 0.0387 - accuracy: 0.9879
# Epoch 10/10
# 14000/14000 [==============================] - 27s 2ms/step - loss: 0.0373 - accuracy: 0.9885
# Accuracy: 98.57
# Confusion matrix
#  [[9754   86]
#  [  61  412]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      9840
#            1       0.83      0.87      0.85       473
#
#     accuracy                           0.99     10313
#    macro avg       0.91      0.93      0.92     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# F1_Score: 0.92
# Best Threshold=0.989040, F-Score=0.883
# PR AUC= 0.916
# Confusion matrix
#  [[9832    8]
#  [  94  379]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      9840
#            1       0.98      0.80      0.88       473
#
#     accuracy                           0.99     10313
#    macro avg       0.98      0.90      0.94     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# Random Forest Classifier
#
# Accuracy: 98.97
# Confusion matrix
#  [[9780   60]
#  [  46  427]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      9840
#            1       0.88      0.90      0.89       473
#
#     accuracy                           0.99     10313
#    macro avg       0.94      0.95      0.94     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# F1_Score: 0.94
# Best Threshold=0.822638, F-Score=0.914
# PR AUC= 0.941
# Confusion matrix
#  [[9831    9]
#  [  68  405]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      9840
#            1       0.98      0.86      0.91       473
#
#     accuracy                           0.99     10313
#    macro avg       0.99      0.93      0.95     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# Fully connected layer
# Epoch 1/10
# 14000/14000 [==============================] - 27s 2ms/step - loss: 0.1673 - accuracy: 0.9361
# Epoch 2/10
# 14000/14000 [==============================] - 28s 2ms/step - loss: 0.0884 - accuracy: 0.9689
# Epoch 3/10
# 14000/14000 [==============================] - 26s 2ms/step - loss: 0.0620 - accuracy: 0.9791
# Epoch 4/10
# 14000/14000 [==============================] - 26s 2ms/step - loss: 0.0519 - accuracy: 0.9829
# Epoch 5/10
# 14000/14000 [==============================] - 26s 2ms/step - loss: 0.0467 - accuracy: 0.9847
# Epoch 6/10
# 14000/14000 [==============================] - 26s 2ms/step - loss: 0.0435 - accuracy: 0.9857
# Epoch 7/10
# 14000/14000 [==============================] - 25s 2ms/step - loss: 0.0411 - accuracy: 0.9865
# Epoch 8/10
# 14000/14000 [==============================] - 26s 2ms/step - loss: 0.0406 - accuracy: 0.9867
# Epoch 9/10
# 14000/14000 [==============================] - 26s 2ms/step - loss: 0.0392 - accuracy: 0.9871
# Epoch 10/10
# 14000/14000 [==============================] - 33s 2ms/step - loss: 0.0392 - accuracy: 0.9872
# Accuracy: 98.59
# Confusion matrix
#  [[9761   79]
#  [  66  407]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      9840
#            1       0.84      0.86      0.85       473
#
#     accuracy                           0.99     10313
#    macro avg       0.92      0.93      0.92     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# F1_Score: 0.92
# Best Threshold=0.915198, F-Score=0.885
# PR AUC= 0.909
# Confusion matrix
#  [[9824   16]
#  [  86  387]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      9840
#            1       0.96      0.82      0.88       473
#
#     accuracy                           0.99     10313
#    macro avg       0.98      0.91      0.94     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# Random Forest Classifier
#
# Accuracy: 98.97
# Confusion matrix
#  [[9781   59]
#  [  47  426]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      9840
#            1       0.88      0.90      0.89       473
#
#     accuracy                           0.99     10313
#    macro avg       0.94      0.95      0.94     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# F1_Score: 0.94
# Best Threshold=0.829292, F-Score=0.913
# PR AUC= 0.940
# Confusion matrix
#  [[9830   10]
#  [  68  405]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      9840
#            1       0.98      0.86      0.91       473
#
#     accuracy                           0.99     10313
#    macro avg       0.98      0.93      0.95     10313
# weighted avg       0.99      0.99      0.99     10313
#
#
# > F1 Score FCL: 0.924 (Độ lệch +- 0.007999999999999985)
# > F1 Score RFC: 0.9399999999999998 (Độ lệch +- 1.1102230246251565e-16)

# %% [markdown]
# ## 3.Train Synthetic - Test Synthetic

# %%
zero_ori = ori_data[ori_data.Class==0]

# %%
train_size0 = 112000
train_size1 = 112000
test_size1 = 492
test_size0 = 492*20

for name, data_path in synth_data:
    print("------------------------------------------", name)
    rfc_f1_list = []
    fcl_f1_list = []
    
    #add synthetic data into ori zero
    gen_data = pd.read_csv(data_path)[data_cols]
    gen_data["Class"] = np.ones(gen_data.shape[0], dtype = int)
    
    print(gen_data)
    
    zero_data = zero_ori.sample(train_size0 + test_size0)
    one_data = gen_data.sample(train_size1+test_size1)
        
    train_data3 = pd.concat([zero_data.iloc[:train_size0], one_data.iloc[:train_size1]], axis = 0)
    train_data3 = train_data3.sample(frac=1).reset_index(drop=True)
    test_data3 = pd.concat([zero_data.iloc[train_size0:train_size0+test_size0], one_data.iloc[train_size1:train_size1+test_size1]], axis = 0)
    test_data3= test_data3.sample(frac=1).reset_index(drop=True)
    
    X_train3, y_train3 = train_data3[data_cols], train_data3["Class"]
    X_test3, y_test3 = test_data3[data_cols], test_data3["Class"]
    X_train3, X_test3 = standard_scaler(X_train3, X_test3)
        
    for i in range(0,LOOP):
        print('----------', LOOP)
        fcl_f1, rfc_f1 = train_evaluate(X_train3, y_train3, X_test3, y_test3)
        fcl_f1_list.append(fcl_f1)
        rfc_f1_list.append(rfc_f1)
        
    print("------------------------------------------", name)    
    print(f'> F1 Score FCL: {np.mean(fcl_f1_list)} (Độ lệch +- {np.std(fcl_f1_list)})')
    print(f'> F1 Score RFC: {np.mean(rfc_f1_list)} (Độ lệch +- {np.std(rfc_f1_list)})')
# Out:
# ------------------------------------------ Synthpop140000
#                V1         V2         V3        V4         V5        V6  \
# 0       -1.396204   2.618584  -2.987193  2.178538  -0.281214 -0.501474
# 1       -6.159607   1.468713  -3.114372  5.153525  -2.470388 -2.735569
# 2      -28.524268  15.365804 -28.923756  6.370895 -22.105532 -4.572498
# 3       -3.291125   0.099249  -4.759158  3.728439  -0.161437 -1.904959
# 4        0.232512   2.994499  -5.052968  5.835566   1.591168 -1.811287
# ...           ...        ...        ...       ...        ...       ...
# 139995 -21.885434   9.843153 -24.098872  6.155789 -16.905611 -4.902997
# 139996  -5.685013   5.776516  -9.775528  6.689951  -4.409844 -0.133493
# 139997  -5.622469   0.577610  -6.934388  2.400031   2.497367 -1.260375
# 139998  -2.326922   0.520539  -1.994122  0.605761  -1.185444 -0.131207
# 139999  -2.866364   4.045601  -5.957706  5.340242  -2.080938 -2.420168
#
#                V7         V8        V9       V10  ...       V21       V22  \
# 0       -1.362388  -0.620953 -0.238253 -5.529131  ...  0.652683  0.893850
# 1       -5.551433   1.066636 -4.322377 -8.537758  ...  0.713559  0.487478
# 2      -19.501084  19.168327 -3.591491 -7.731071  ...  1.816520 -2.175815
# 3       -0.118841   0.547069 -2.451251 -5.974925  ...  0.320474 -0.122724
# 4       -0.781880   0.303253 -3.747646 -3.419207  ...  0.249023 -0.614880
# ...           ...        ...       ...       ...  ...       ...       ...
# 139995 -13.897827  14.116002 -4.358441 -8.581266  ...  1.754608 -1.960974
# 139996  -4.205164   0.979334 -3.429304 -4.851487  ...  5.453672  0.719526
# 139997  -2.167860  -0.728207 -2.828287 -3.232153  ...  0.249023 -0.990303
# 139998  -1.082511  -0.246922 -0.765054  0.644550  ...  0.490183 -0.466245
# 139999  -4.716143   1.029246 -4.382713 -8.099119  ...  2.674466  0.793736
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0       0.190944 -0.601505 -0.527114 -0.624085  0.756953  0.201156   60.00
# 1      -0.547955 -0.548504  0.125865  0.112671 -0.766848  0.422184    7.52
# 2      -1.093104  0.152234  1.715997 -0.966564  1.255649  0.422492   99.99
# 3      -1.017502 -0.480549  0.057425  0.064558  0.516274 -0.117140  296.00
# 4      -0.286080  0.103916  0.147171  0.060171  0.300193  0.402528    2.00
# ...          ...       ...       ...       ...       ...       ...     ...
# 139995 -0.766495  0.112540  1.119193  0.507963 -1.464630  1.405141   99.99
# 139996 -0.141879  0.014960  0.247435 -0.136312  0.900925  0.315645  346.94
# 139997 -0.226017  0.111635  0.349212  0.691775 -0.146102 -0.050117    7.06
# 139998  0.092891  0.600742 -0.956062  2.745261 -0.308555 -0.123391    1.00
# 139999 -0.148486 -0.360848  0.157771  1.075295  1.277707  0.541148   45.64
#
#         Class
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 139995      1
# 139996      1
# 139997      1
# 139998      1
# 139999      1
#
# [140000 rows x 30 columns]
# Fully connected layer
#
# Epoch 1/10
# 14000/14000 [==============================] - 31s 2ms/step - loss: 0.1636 - accuracy: 0.9402
# Epoch 2/10
# 14000/14000 [==============================] - 33s 2ms/step - loss: 0.0831 - accuracy: 0.9715
# Epoch 3/10
# 14000/14000 [==============================] - 33s 2ms/step - loss: 0.0618 - accuracy: 0.9798
# Epoch 4/10
# 14000/14000 [==============================] - 35s 2ms/step - loss: 0.0562 - accuracy: 0.9820
# Epoch 5/10
# 14000/14000 [==============================] - 37s 3ms/step - loss: 0.0541 - accuracy: 0.9828
# Epoch 6/10
# 14000/14000 [==============================] - 32s 2ms/step - loss: 0.0524 - accuracy: 0.9830
# Epoch 7/10
# 14000/14000 [==============================] - 35s 2ms/step - loss: 0.0516 - accuracy: 0.9835
# Epoch 8/10
# 14000/14000 [==============================] - 35s 2ms/step - loss: 0.0511 - accuracy: 0.9835
# Epoch 9/10
# 14000/14000 [==============================] - 32s 2ms/step - loss: 0.0497 - accuracy: 0.9840
# Epoch 10/10
# 14000/14000 [==============================] - 35s 2ms/step - loss: 0.0481 - accuracy: 0.9843
# Accuracy: 99.24
# Confusion matrix
#  [[9770   70]
#  [   9  483]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      9840
#            1       0.87      0.98      0.92       492
#
#     accuracy                           0.99     10332
#    macro avg       0.94      0.99      0.96     10332
# weighted avg       0.99      0.99      0.99     10332
#
#
# F1_Score: 0.96
# Best Threshold=0.906009, F-Score=0.973
# PR AUC= 0.990
# Confusion matrix
#  [[9833    7]
#  [  20  472]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9840
#            1       0.99      0.96      0.97       492
#
#     accuracy                           1.00     10332
#    macro avg       0.99      0.98      0.99     10332
# weighted avg       1.00      1.00      1.00     10332
#
#
# Random Forest Classifier
#
# Accuracy: 99.33
# Confusion matrix
#  [[9797   43]
#  [  26  466]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9840
#            1       0.92      0.95      0.93       492
#
#     accuracy                           0.99     10332
#    macro avg       0.96      0.97      0.96     10332
# weighted avg       0.99      0.99      0.99     10332
#
#
# F1_Score: 0.96
# Best Threshold=0.684572, F-Score=0.943
# PR AUC= 0.966
# Confusion matrix
#  [[9823   17]
#  [  39  453]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9840
#            1       0.96      0.92      0.94       492
#
#     accuracy                           0.99     10332
#    macro avg       0.98      0.96      0.97     10332
# weighted avg       0.99      0.99      0.99     10332
#
#
# Fully connected layer
#
# Epoch 1/10
# 14000/14000 [==============================] - 38s 3ms/step - loss: 0.1458 - accuracy: 0.9390
# Epoch 2/10
# 14000/14000 [==============================] - 36s 3ms/step - loss: 0.0856 - accuracy: 0.9689
# Epoch 3/10
# 14000/14000 [==============================] - 35s 2ms/step - loss: 0.0600 - accuracy: 0.9795
# Epoch 4/10
# 14000/14000 [==============================] - 33s 2ms/step - loss: 0.0466 - accuracy: 0.9852
# Epoch 5/10
# 14000/14000 [==============================] - 33s 2ms/step - loss: 0.0401 - accuracy: 0.9877
# Epoch 6/10
# 14000/14000 [==============================] - 34s 2ms/step - loss: 0.0330 - accuracy: 0.9900
# Epoch 7/10
# 14000/14000 [==============================] - 32s 2ms/step - loss: 0.0286 - accuracy: 0.9915
# Epoch 8/10
# 14000/14000 [==============================] - 32s 2ms/step - loss: 0.0264 - accuracy: 0.9922
# Epoch 9/10
# 14000/14000 [==============================] - 36s 3ms/step - loss: 0.0244 - accuracy: 0.9930
# Epoch 10/10
# 14000/14000 [==============================] - 35s 3ms/step - loss: 0.0235 - accuracy: 0.9932
# Accuracy: 99.67
# Confusion matrix
#  [[9809   31]
#  [   3  489]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9840
#            1       0.94      0.99      0.97       492
#
#     accuracy                           1.00     10332
#    macro avg       0.97      1.00      0.98     10332
# weighted avg       1.00      1.00      1.00     10332
#
#
# F1_Score: 0.98
# Best Threshold=0.823522, F-Score=0.983
# PR AUC= 0.989
# Confusion matrix
#  [[9829   11]
#  [   7  485]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9840
#            1       0.98      0.99      0.98       492
#
#     accuracy                           1.00     10332
#    macro avg       0.99      0.99      0.99     10332
# weighted avg       1.00      1.00      1.00     10332
#
#
# Random Forest Classifier
#
# Accuracy: 99.34
# Confusion matrix
#  [[9797   43]
#  [  25  467]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9840
#            1       0.92      0.95      0.93       492
#
#     accuracy                           0.99     10332
#    macro avg       0.96      0.97      0.96     10332
# weighted avg       0.99      0.99      0.99     10332
#
#
# F1_Score: 0.96
# Best Threshold=0.692359, F-Score=0.944
# PR AUC= 0.963
# Confusion matrix
#  [[9825   15]
#  [  40  452]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9840
#            1       0.97      0.92      0.94       492
#
#     accuracy                           0.99     10332
#    macro avg       0.98      0.96      0.97     10332
# weighted avg       0.99      0.99      0.99     10332
#
#
# Fully connected layer
# Epoch 1/10
# 14000/14000 [==============================] - 31s 2ms/step - loss: 0.1611 - accuracy: 0.9391
# Epoch 2/10
# 14000/14000 [==============================] - 30s 2ms/step - loss: 0.0808 - accuracy: 0.9720
# Epoch 3/10
# 14000/14000 [==============================] - 30s 2ms/step - loss: 0.0640 - accuracy: 0.9788
# Epoch 4/10
# 14000/14000 [==============================] - 35s 3ms/step - loss: 0.0539 - accuracy: 0.9825
# Epoch 5/10
# 14000/14000 [==============================] - 35s 3ms/step - loss: 0.0489 - accuracy: 0.9843
# Epoch 6/10
# 14000/14000 [==============================] - 36s 3ms/step - loss: 0.0456 - accuracy: 0.9852
# Epoch 7/10
# 14000/14000 [==============================] - 28s 2ms/step - loss: 0.0434 - accuracy: 0.9861 0s - loss:
# Epoch 8/10
# 14000/14000 [==============================] - 32s 2ms/step - loss: 0.0412 - accuracy: 0.9868
# Epoch 9/10
# 14000/14000 [==============================] - 31s 2ms/step - loss: 0.0394 - accuracy: 0.9873
# Epoch 10/10
# 14000/14000 [==============================] - 30s 2ms/step - loss: 0.0381 - accuracy: 0.9876
# Accuracy: 99.3
# Confusion matrix
#  [[9774   66]
#  [   6  486]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      9840
#            1       0.88      0.99      0.93       492
#
#     accuracy                           0.99     10332
#    macro avg       0.94      0.99      0.96     10332
# weighted avg       0.99      0.99      0.99     10332
#
#
# F1_Score: 0.96
# Best Threshold=0.927184, F-Score=0.974
# PR AUC= 0.989
# Confusion matrix
#  [[9833    7]
#  [  19  473]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9840
#            1       0.99      0.96      0.97       492
#
#     accuracy                           1.00     10332
#    macro avg       0.99      0.98      0.99     10332
# weighted avg       1.00      1.00      1.00     10332
#
#
# Random Forest Classifier
#
# Accuracy: 99.38
# Confusion matrix
#  [[9801   39]
#  [  25  467]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9840
#            1       0.92      0.95      0.94       492
#
#     accuracy                           0.99     10332
#    macro avg       0.96      0.97      0.97     10332
# weighted avg       0.99      0.99      0.99     10332
#
#
# F1_Score: 0.97
# Best Threshold=0.698225, F-Score=0.939
# PR AUC= 0.965
# Confusion matrix
#  [[9824   16]
#  [  43  449]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9840
#            1       0.97      0.91      0.94       492
#
#     accuracy                           0.99     10332
#    macro avg       0.98      0.96      0.97     10332
# weighted avg       0.99      0.99      0.99     10332
#
#
# Fully connected layer
#
# Epoch 1/10
# 14000/14000 [==============================] - 32s 2ms/step - loss: 0.1648 - accuracy: 0.9403
# Epoch 2/10
# 14000/14000 [==============================] - 29s 2ms/step - loss: 0.0951 - accuracy: 0.9666
# Epoch 3/10
# 14000/14000 [==============================] - 31s 2ms/step - loss: 0.0726 - accuracy: 0.9754
# Epoch 4/10
# 14000/14000 [==============================] - 36s 3ms/step - loss: 0.0593 - accuracy: 0.9813
# Epoch 5/10
# 14000/14000 [==============================] - 33s 2ms/step - loss: 0.0524 - accuracy: 0.9837
# Epoch 6/10
# 14000/14000 [==============================] - 33s 2ms/step - loss: 0.0484 - accuracy: 0.9846
# Epoch 7/10
# 14000/14000 [==============================] - 33s 2ms/step - loss: 0.0467 - accuracy: 0.9851
# Epoch 8/10
# 14000/14000 [==============================] - 33s 2ms/step - loss: 0.0449 - accuracy: 0.9859
# Epoch 9/10
# 14000/14000 [==============================] - 33s 2ms/step - loss: 0.0432 - accuracy: 0.9864
# Epoch 10/10
# 14000/14000 [==============================] - 32s 2ms/step - loss: 0.0416 - accuracy: 0.9869
# Accuracy: 99.29
# Confusion matrix
#  [[9779   61]
#  [  12  480]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      9840
#            1       0.89      0.98      0.93       492
#
#     accuracy                           0.99     10332
#    macro avg       0.94      0.98      0.96     10332
# weighted avg       0.99      0.99      0.99     10332
#
#
# F1_Score: 0.96
# Best Threshold=0.945926, F-Score=0.968
# PR AUC= 0.984
# Confusion matrix
#  [[9829   11]
#  [  21  471]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9840
#            1       0.98      0.96      0.97       492
#
#     accuracy                           1.00     10332
#    macro avg       0.99      0.98      0.98     10332
# weighted avg       1.00      1.00      1.00     10332
#
#
# Random Forest Classifier
#
# Accuracy: 99.35
# Confusion matrix
#  [[9799   41]
#  [  26  466]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9840
#            1       0.92      0.95      0.93       492
#
#     accuracy                           0.99     10332
#    macro avg       0.96      0.97      0.96     10332
# weighted avg       0.99      0.99      0.99     10332
#
#
# F1_Score: 0.96
# Best Threshold=0.741679, F-Score=0.943
# PR AUC= 0.966
# Confusion matrix
#  [[9830   10]
#  [  45  447]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9840
#            1       0.98      0.91      0.94       492
#
#     accuracy                           0.99     10332
#    macro avg       0.99      0.95      0.97     10332
# weighted avg       0.99      0.99      0.99     10332
#
#
# Fully connected layer
#
# Epoch 1/10
# 14000/14000 [==============================] - 28s 2ms/step - loss: 0.1682 - accuracy: 0.9378
# Epoch 2/10
# 14000/14000 [==============================] - 28s 2ms/step - loss: 0.0887 - accuracy: 0.9689
# Epoch 3/10
# 14000/14000 [==============================] - 29s 2ms/step - loss: 0.0592 - accuracy: 0.9803
# Epoch 4/10
# 14000/14000 [==============================] - 28s 2ms/step - loss: 0.0487 - accuracy: 0.9841
# Epoch 5/10
# 14000/14000 [==============================] - 28s 2ms/step - loss: 0.0439 - accuracy: 0.9860
# Epoch 6/10
# 14000/14000 [==============================] - 29s 2ms/step - loss: 0.0409 - accuracy: 0.9871
# Epoch 7/10
# 14000/14000 [==============================] - 29s 2ms/step - loss: 0.0388 - accuracy: 0.9877
# Epoch 8/10
# 14000/14000 [==============================] - 29s 2ms/step - loss: 0.0361 - accuracy: 0.9886
# Epoch 9/10
# 14000/14000 [==============================] - 30s 2ms/step - loss: 0.0322 - accuracy: 0.9899
# Epoch 10/10
# 14000/14000 [==============================] - 29s 2ms/step - loss: 0.0294 - accuracy: 0.9908
# Accuracy: 99.81
# Confusion matrix
#  [[9823   17]
#  [   3  489]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9840
#            1       0.97      0.99      0.98       492
#
#     accuracy                           1.00     10332
#    macro avg       0.98      1.00      0.99     10332
# weighted avg       1.00      1.00      1.00     10332
#
#
# F1_Score: 0.99
# Best Threshold=0.735954, F-Score=0.984
# PR AUC= 0.994
# Confusion matrix
#  [[9830   10]
#  [   7  485]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9840
#            1       0.98      0.99      0.98       492
#
#     accuracy                           1.00     10332
#    macro avg       0.99      0.99      0.99     10332
# weighted avg       1.00      1.00      1.00     10332
#
#
# Random Forest Classifier
#
# Accuracy: 99.37
# Confusion matrix
#  [[9799   41]
#  [  24  468]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9840
#            1       0.92      0.95      0.94       492
#
#     accuracy                           0.99     10332
#    macro avg       0.96      0.97      0.97     10332
# weighted avg       0.99      0.99      0.99     10332
#
#
# F1_Score: 0.97
# Best Threshold=0.718467, F-Score=0.940
# PR AUC= 0.967
# Confusion matrix
#  [[9827   13]
#  [  45  447]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9840
#            1       0.97      0.91      0.94       492
#
#     accuracy                           0.99     10332
#    macro avg       0.98      0.95      0.97     10332
# weighted avg       0.99      0.99      0.99     10332
#
#
# Fully connected layer
# Epoch 1/10
# 14000/14000 [==============================] - 30s 2ms/step - loss: 0.1668 - accuracy: 0.9360
# Epoch 2/10
# 14000/14000 [==============================] - 28s 2ms/step - loss: 0.0829 - accuracy: 0.9722
# Epoch 3/10
# 14000/14000 [==============================] - 29s 2ms/step - loss: 0.0654 - accuracy: 0.9794
# Epoch 4/10
# 14000/14000 [==============================] - 29s 2ms/step - loss: 0.0551 - accuracy: 0.9826
# Epoch 5/10
# 14000/14000 [==============================] - 30s 2ms/step - loss: 0.0488 - accuracy: 0.9840
# Epoch 6/10
# 14000/14000 [==============================] - 31s 2ms/step - loss: 0.0448 - accuracy: 0.9851
# Epoch 7/10
# 14000/14000 [==============================] - 30s 2ms/step - loss: 0.0419 - accuracy: 0.9858
# Epoch 8/10
# 14000/14000 [==============================] - 30s 2ms/step - loss: 0.0398 - accuracy: 0.9864
# Epoch 9/10
# 14000/14000 [==============================] - 32s 2ms/step - loss: 0.0381 - accuracy: 0.9869
# Epoch 10/10
# 14000/14000 [==============================] - 33s 2ms/step - loss: 0.0370 - accuracy: 0.9872
# Accuracy: 98.97
# Confusion matrix
#  [[9741   99]
#  [   7  485]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      9840
#            1       0.83      0.99      0.90       492
#
#     accuracy                           0.99     10332
#    macro avg       0.91      0.99      0.95     10332
# weighted avg       0.99      0.99      0.99     10332
#
#
# F1_Score: 0.95
# Best Threshold=0.946007, F-Score=0.975
# PR AUC= 0.988
# Confusion matrix
#  [[9834    6]
#  [  19  473]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9840
#            1       0.99      0.96      0.97       492
#
#     accuracy                           1.00     10332
#    macro avg       0.99      0.98      0.99     10332
# weighted avg       1.00      1.00      1.00     10332
#
#
# Random Forest Classifier
#
# Accuracy: 99.32
# Confusion matrix
#  [[9795   45]
#  [  25  467]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9840
#            1       0.91      0.95      0.93       492
#
#     accuracy                           0.99     10332
#    macro avg       0.95      0.97      0.96     10332
# weighted avg       0.99      0.99      0.99     10332
#
#
# F1_Score: 0.96
# Best Threshold=0.698089, F-Score=0.943
# PR AUC= 0.964
# Confusion matrix
#  [[9825   15]
#  [  41  451]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9840
#            1       0.97      0.92      0.94       492
#
#     accuracy                           0.99     10332
#    macro avg       0.98      0.96      0.97     10332
# weighted avg       0.99      0.99      0.99     10332
#
#
# Fully connected layer
#
# Epoch 1/10
# 14000/14000 [==============================] - 27s 2ms/step - loss: 0.1642 - accuracy: 0.9393
# Epoch 2/10
# 14000/14000 [==============================] - 33s 2ms/step - loss: 0.0899 - accuracy: 0.9683
# Epoch 3/10
# 14000/14000 [==============================] - 28s 2ms/step - loss: 0.0627 - accuracy: 0.9790
# Epoch 4/10
# 14000/14000 [==============================] - 37s 3ms/step - loss: 0.0495 - accuracy: 0.9840 0s - loss: 0.0
# Epoch 5/10
# 14000/14000 [==============================] - 34s 2ms/step - loss: 0.0433 - accuracy: 0.9861
# Epoch 6/10
# 14000/14000 [==============================] - 31s 2ms/step - loss: 0.0398 - accuracy: 0.9875
# Epoch 7/10
# 14000/14000 [==============================] - 27s 2ms/step - loss: 0.0365 - accuracy: 0.9887
# Epoch 8/10
# 14000/14000 [==============================] - 26s 2ms/step - loss: 0.0343 - accuracy: 0.9895
# Epoch 9/10
# 14000/14000 [==============================] - 25s 2ms/step - loss: 0.0333 - accuracy: 0.9901
# Epoch 10/10
# 14000/14000 [==============================] - 27s 2ms/step - loss: 0.0320 - accuracy: 0.9904
# Accuracy: 99.63
# Confusion matrix
#  [[9809   31]
#  [   7  485]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9840
#            1       0.94      0.99      0.96       492
#
#     accuracy                           1.00     10332
#    macro avg       0.97      0.99      0.98     10332
# weighted avg       1.00      1.00      1.00     10332
#
#
# F1_Score: 0.98
# Best Threshold=0.729125, F-Score=0.976
# PR AUC= 0.990
# Confusion matrix
#  [[9826   14]
#  [  11  481]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9840
#            1       0.97      0.98      0.97       492
#
#     accuracy                           1.00     10332
#    macro avg       0.99      0.99      0.99     10332
# weighted avg       1.00      1.00      1.00     10332
#
#
# Random Forest Classifier
#
# Accuracy: 99.37
# Confusion matrix
#  [[9800   40]
#  [  25  467]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9840
#            1       0.92      0.95      0.93       492
#
#     accuracy                           0.99     10332
#    macro avg       0.96      0.97      0.97     10332
# weighted avg       0.99      0.99      0.99     10332
#
#
# F1_Score: 0.97
# Best Threshold=0.680792, F-Score=0.942
# PR AUC= 0.968
# Confusion matrix
#  [[9825   15]
#  [  42  450]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9840
#            1       0.97      0.91      0.94       492
#
#     accuracy                           0.99     10332
#    macro avg       0.98      0.96      0.97     10332
# weighted avg       0.99      0.99      0.99     10332
#
#
# Fully connected layer
#
# Epoch 1/10
# 14000/14000 [==============================] - 29s 2ms/step - loss: 0.1431 - accuracy: 0.9447
# Epoch 2/10
# 14000/14000 [==============================] - 28s 2ms/step - loss: 0.0767 - accuracy: 0.9726
# Epoch 3/10
# 14000/14000 [==============================] - 29s 2ms/step - loss: 0.0584 - accuracy: 0.9797
# Epoch 4/10
# 14000/14000 [==============================] - 31s 2ms/step - loss: 0.0484 - accuracy: 0.9843
# Epoch 5/10
# 14000/14000 [==============================] - 27s 2ms/step - loss: 0.0430 - accuracy: 0.9865
# Epoch 6/10
# 14000/14000 [==============================] - 27s 2ms/step - loss: 0.0403 - accuracy: 0.9872
# Epoch 7/10
# 14000/14000 [==============================] - 30s 2ms/step - loss: 0.0385 - accuracy: 0.9877
# Epoch 8/10
# 14000/14000 [==============================] - 25s 2ms/step - loss: 0.0371 - accuracy: 0.9882
# Epoch 9/10
# 14000/14000 [==============================] - 26s 2ms/step - loss: 0.0356 - accuracy: 0.9886
# Epoch 10/10
# 14000/14000 [==============================] - 26s 2ms/step - loss: 0.0352 - accuracy: 0.9891 0s - loss: 0.0352 - accuracy: 0.
# Accuracy: 99.08
# Confusion matrix
#  [[9752   88]
#  [   7  485]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      9840
#            1       0.85      0.99      0.91       492
#
#     accuracy                           0.99     10332
#    macro avg       0.92      0.99      0.95     10332
# weighted avg       0.99      0.99      0.99     10332
#
#
# F1_Score: 0.95
# Best Threshold=0.917356, F-Score=0.966
# PR AUC= 0.985
# Confusion matrix
#  [[9822   18]
#  [  17  475]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9840
#            1       0.96      0.97      0.96       492
#
#     accuracy                           1.00     10332
#    macro avg       0.98      0.98      0.98     10332
# weighted avg       1.00      1.00      1.00     10332
#
#
# Random Forest Classifier
#
# Accuracy: 99.38
# Confusion matrix
#  [[9800   40]
#  [  24  468]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9840
#            1       0.92      0.95      0.94       492
#
#     accuracy                           0.99     10332
#    macro avg       0.96      0.97      0.97     10332
# weighted avg       0.99      0.99      0.99     10332
#
#
# F1_Score: 0.97
# Best Threshold=0.754851, F-Score=0.942
# PR AUC= 0.964
# Confusion matrix
#  [[9832    8]
#  [  48  444]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9840
#            1       0.98      0.90      0.94       492
#
#     accuracy                           0.99     10332
#    macro avg       0.99      0.95      0.97     10332
# weighted avg       0.99      0.99      0.99     10332
#
#
# Fully connected layer
# Epoch 1/10
# 14000/14000 [==============================] - 27s 2ms/step - loss: 0.1630 - accuracy: 0.9424
# Epoch 2/10
# 14000/14000 [==============================] - 25s 2ms/step - loss: 0.0830 - accuracy: 0.9707
# Epoch 3/10
# 14000/14000 [==============================] - 25s 2ms/step - loss: 0.0670 - accuracy: 0.9776
# Epoch 4/10
# 14000/14000 [==============================] - 26s 2ms/step - loss: 0.0577 - accuracy: 0.9809
# Epoch 5/10
# 14000/14000 [==============================] - 29s 2ms/step - loss: 0.0463 - accuracy: 0.9853 0s - loss: 0.0465 - ac
# Epoch 6/10
# 14000/14000 [==============================] - 27s 2ms/step - loss: 0.0405 - accuracy: 0.9872
# Epoch 7/10
# 14000/14000 [==============================] - 36s 3ms/step - loss: 0.0383 - accuracy: 0.9879
# Epoch 8/10
# 14000/14000 [==============================] - 39s 3ms/step - loss: 0.0370 - accuracy: 0.9880
# Epoch 9/10
# 14000/14000 [==============================] - 36s 3ms/step - loss: 0.0361 - accuracy: 0.9885
# Epoch 10/10
# 14000/14000 [==============================] - 33s 2ms/step - loss: 0.0352 - accuracy: 0.9889
# Accuracy: 99.05
# Confusion matrix
#  [[9751   89]
#  [   9  483]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      9840
#            1       0.84      0.98      0.91       492
#
#     accuracy                           0.99     10332
#    macro avg       0.92      0.99      0.95     10332
# weighted avg       0.99      0.99      0.99     10332
#
#
# F1_Score: 0.95
# Best Threshold=0.940711, F-Score=0.970
# PR AUC= 0.987
# Confusion matrix
#  [[9828   12]
#  [  18  474]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9840
#            1       0.98      0.96      0.97       492
#
#     accuracy                           1.00     10332
#    macro avg       0.99      0.98      0.98     10332
# weighted avg       1.00      1.00      1.00     10332
#
#
# Random Forest Classifier
#
# Accuracy: 99.37
# Confusion matrix
#  [[9800   40]
#  [  25  467]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9840
#            1       0.92      0.95      0.93       492
#
#     accuracy                           0.99     10332
#    macro avg       0.96      0.97      0.97     10332
# weighted avg       0.99      0.99      0.99     10332
#
#
# F1_Score: 0.97
# Best Threshold=0.677471, F-Score=0.944
# PR AUC= 0.967
# Confusion matrix
#  [[9824   16]
#  [  39  453]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9840
#            1       0.97      0.92      0.94       492
#
#     accuracy                           0.99     10332
#    macro avg       0.98      0.96      0.97     10332
# weighted avg       0.99      0.99      0.99     10332
#
#
# Fully connected layer
#
# Epoch 1/10
# 14000/14000 [==============================] - 37s 3ms/step - loss: 0.1562 - accuracy: 0.9452
# Epoch 2/10
# 14000/14000 [==============================] - 36s 3ms/step - loss: 0.0966 - accuracy: 0.9661
# Epoch 3/10
# 14000/14000 [==============================] - 34s 2ms/step - loss: 0.0764 - accuracy: 0.9739
# Epoch 4/10
# 14000/14000 [==============================] - 39s 3ms/step - loss: 0.0635 - accuracy: 0.9798 0s - loss: 0.0640 -  - ETA: 0s - los
# Epoch 5/10
# 14000/14000 [==============================] - 34s 2ms/step - loss: 0.0525 - accuracy: 0.9838
# Epoch 6/10
# 14000/14000 [==============================] - 34s 2ms/step - loss: 0.0470 - accuracy: 0.9853
# Epoch 7/10
# 14000/14000 [==============================] - 39s 3ms/step - loss: 0.0454 - accuracy: 0.9862 0s - l - ETA: 0s - loss: 0.0453 - ac
# Epoch 8/10
# 14000/14000 [==============================] - 34s 2ms/step - loss: 0.0432 - accuracy: 0.9866
# Epoch 9/10
# 14000/14000 [==============================] - 31s 2ms/step - loss: 0.0414 - accuracy: 0.9873
# Epoch 10/10
# 14000/14000 [==============================] - 39s 3ms/step - loss: 0.0399 - accuracy: 0.9876
# Accuracy: 99.08
# Confusion matrix
#  [[9754   86]
#  [   9  483]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      9840
#            1       0.85      0.98      0.91       492
#
#     accuracy                           0.99     10332
#    macro avg       0.92      0.99      0.95     10332
# weighted avg       0.99      0.99      0.99     10332
#
#
# F1_Score: 0.95
# Best Threshold=0.932521, F-Score=0.965
# PR AUC= 0.985
# Confusion matrix
#  [[9826   14]
#  [  21  471]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9840
#            1       0.97      0.96      0.96       492
#
#     accuracy                           1.00     10332
#    macro avg       0.98      0.98      0.98     10332
# weighted avg       1.00      1.00      1.00     10332
#
#
# Random Forest Classifier
#
# Accuracy: 99.32
# Confusion matrix
#  [[9795   45]
#  [  25  467]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9840
#            1       0.91      0.95      0.93       492
#
#     accuracy                           0.99     10332
#    macro avg       0.95      0.97      0.96     10332
# weighted avg       0.99      0.99      0.99     10332
#
#
# F1_Score: 0.96
# Best Threshold=0.733870, F-Score=0.942
# PR AUC= 0.967
# Confusion matrix
#  [[9829   11]
#  [  45  447]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9840
#            1       0.98      0.91      0.94       492
#
#     accuracy                           0.99     10332
#    macro avg       0.99      0.95      0.97     10332
# weighted avg       0.99      0.99      0.99     10332
#
#
# > F1 Score FCL: 0.9629999999999999 (Độ lệch +- 0.014177446878757839)
# > F1 Score RFC: 0.9649999999999999 (Độ lệch +- 0.0050000000000000044)

# %% [markdown]
# ## 4. Dataset = ori + gen
#     Train 112k 0 112k 1
#     Test 492*2 0 492 1

# %%
train_size0 = 112000
train_size1 = 112000
test_size1 = 1000
test_size0 = test_size1*20

for name, data_path in synth_data:
    print("------------------------------------------", name)
    rfc_f1_list = []
    fcl_f1_list = []
    
    #combine 2 dataset
    gen_data = pd.read_csv(data_path)[data_cols]
    gen_data["Class"] = np.ones(gen_data.shape[0], dtype = int)
    data4 = pd.concat([gen_data, ori_data], axis=0) 
    
    #split train test
    zero_data = data4[data4.Class == 0].sample(train_size0 + test_size0)
    one_data = data4[data4.Class == 1].sample(train_size1+test_size1)
        
    train_data4 = pd.concat([zero_data.iloc[:train_size0], one_data.iloc[:train_size1]], axis = 0)
    train_data4 = train_data4.sample(frac=1).reset_index(drop=True)
    test_data4 = pd.concat([zero_data.iloc[train_size0:train_size0+test_size0], one_data.iloc[train_size1:train_size1+test_size1]], axis = 0)
    test_data4 = test_data4.sample(frac=1).reset_index(drop=True)
    
    X_train4, y_train4 = train_data4[data_cols], train_data4["Class"]
    X_test4, y_test4 = test_data4[data_cols], test_data4["Class"]
    X_train4, X_test4 = standard_scaler(X_train4, X_test4)
        
    for i in range(0,LOOP):
        print("Train inter", i)
        fcl_f1, rfc_f1 = train_evaluate(X_train4, y_train4, X_test4, y_test4)
        fcl_f1_list.append(fcl_f1)
        rfc_f1_list.append(rfc_f1)
        
    print(f'> F1 Score FCL: {np.mean(fcl_f1_list)} (Độ lệch +- {np.std(fcl_f1_list)})')
    print(f'> F1 Score RFC: {np.mean(rfc_f1_list)} (Độ lệch +- {np.std(rfc_f1_list)})')
# Out:
# ------------------------------------------ Synthpop140000
# Train inter 10
# Fully connected layer
#
# Epoch 1/10
# 14000/14000 [==============================] - 32s 2ms/step - loss: 0.1569 - accuracy: 0.9357
# Epoch 2/10
# 14000/14000 [==============================] - 45s 3ms/step - loss: 0.0795 - accuracy: 0.9722
# Epoch 3/10
# 14000/14000 [==============================] - 42s 3ms/step - loss: 0.0569 - accuracy: 0.9805
# Epoch 4/10
# 14000/14000 [==============================] - 48s 3ms/step - loss: 0.0408 - accuracy: 0.9870
# Epoch 5/10
# 14000/14000 [==============================] - 34s 2ms/step - loss: 0.0341 - accuracy: 0.9893
# Epoch 6/10
# 14000/14000 [==============================] - 33s 2ms/step - loss: 0.0301 - accuracy: 0.9905
# Epoch 7/10
# 14000/14000 [==============================] - 33s 2ms/step - loss: 0.0279 - accuracy: 0.9915
# Epoch 8/10
# 14000/14000 [==============================] - 31s 2ms/step - loss: 0.0274 - accuracy: 0.9916
# Epoch 9/10
# 14000/14000 [==============================] - 30s 2ms/step - loss: 0.0262 - accuracy: 0.9923
# Epoch 10/10
# 14000/14000 [==============================] - 34s 2ms/step - loss: 0.0255 - accuracy: 0.9924
# Accuracy: 99.57
# Confusion matrix
#  [[19917    83]
#  [    8   992]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     20000
#            1       0.92      0.99      0.96      1000
#
#     accuracy                           1.00     21000
#    macro avg       0.96      0.99      0.98     21000
# weighted avg       1.00      1.00      1.00     21000
#
#
# F1_Score: 0.98
# Best Threshold=0.916062, F-Score=0.981
# PR AUC= 0.993
# Confusion matrix
#  [[19985    15]
#  [   23   977]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     20000
#            1       0.98      0.98      0.98      1000
#
#     accuracy                           1.00     21000
#    macro avg       0.99      0.99      0.99     21000
# weighted avg       1.00      1.00      1.00     21000
#
#
# Random Forest Classifier
#
# Accuracy: 99.31
# Confusion matrix
#  [[19898   102]
#  [   43   957]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     20000
#            1       0.90      0.96      0.93      1000
#
#     accuracy                           0.99     21000
#    macro avg       0.95      0.98      0.96     21000
# weighted avg       0.99      0.99      0.99     21000
#
#
# F1_Score: 0.96
# Best Threshold=0.746119, F-Score=0.948
# PR AUC= 0.974
# Confusion matrix
#  [[19973    27]
#  [   75   925]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     20000
#            1       0.97      0.93      0.95      1000
#
#     accuracy                           1.00     21000
#    macro avg       0.98      0.96      0.97     21000
# weighted avg       1.00      1.00      1.00     21000
#
#
# Train inter 10
# Fully connected layer
#
# Epoch 1/10
# 14000/14000 [==============================] - 31s 2ms/step - loss: 0.1562 - accuracy: 0.9433
# Epoch 2/10
# 14000/14000 [==============================] - 30s 2ms/step - loss: 0.0948 - accuracy: 0.9667
# Epoch 3/10
# 14000/14000 [==============================] - 31s 2ms/step - loss: 0.0786 - accuracy: 0.9736
# Epoch 4/10
# 14000/14000 [==============================] - 31s 2ms/step - loss: 0.0604 - accuracy: 0.9811
# Epoch 5/10
# 14000/14000 [==============================] - 32s 2ms/step - loss: 0.0480 - accuracy: 0.9853
# Epoch 6/10
# 14000/14000 [==============================] - 37s 3ms/step - loss: 0.0425 - accuracy: 0.9869
# Epoch 7/10
# 14000/14000 [==============================] - 32s 2ms/step - loss: 0.0393 - accuracy: 0.9880
# Epoch 8/10
# 14000/14000 [==============================] - 32s 2ms/step - loss: 0.0370 - accuracy: 0.9885
# Epoch 9/10
# 14000/14000 [==============================] - 31s 2ms/step - loss: 0.0352 - accuracy: 0.9892 0s - loss: 0.0352 - accuracy: 0.98
# Epoch 10/10
# 14000/14000 [==============================] - 31s 2ms/step - loss: 0.0345 - accuracy: 0.9894
# Accuracy: 99.42
# Confusion matrix
#  [[19891   109]
#  [   12   988]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     20000
#            1       0.90      0.99      0.94      1000
#
#     accuracy                           0.99     21000
#    macro avg       0.95      0.99      0.97     21000
# weighted avg       0.99      0.99      0.99     21000
#
#
# F1_Score: 0.97
# Best Threshold=0.862146, F-Score=0.975
# PR AUC= 0.991
# Confusion matrix
#  [[19979    21]
#  [   30   970]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     20000
#            1       0.98      0.97      0.97      1000
#
#     accuracy                           1.00     21000
#    macro avg       0.99      0.98      0.99     21000
# weighted avg       1.00      1.00      1.00     21000
#
#
# Random Forest Classifier
#
# Accuracy: 99.32
# Confusion matrix
#  [[19901    99]
#  [   43   957]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     20000
#            1       0.91      0.96      0.93      1000
#
#     accuracy                           0.99     21000
#    macro avg       0.95      0.98      0.96     21000
# weighted avg       0.99      0.99      0.99     21000
#
#
# F1_Score: 0.96
# Best Threshold=0.735237, F-Score=0.949
# PR AUC= 0.975
# Confusion matrix
#  [[19971    29]
#  [   72   928]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     20000
#            1       0.97      0.93      0.95      1000
#
#     accuracy                           1.00     21000
#    macro avg       0.98      0.96      0.97     21000
# weighted avg       1.00      1.00      1.00     21000
#
#
# Train inter 10
# Fully connected layer
#
# Epoch 1/10
# 14000/14000 [==============================] - 28s 2ms/step - loss: 0.1535 - accuracy: 0.9424
# Epoch 2/10
# 14000/14000 [==============================] - 25s 2ms/step - loss: 0.0929 - accuracy: 0.9672
# Epoch 3/10
# 14000/14000 [==============================] - 28s 2ms/step - loss: 0.0682 - accuracy: 0.9765
# Epoch 4/10
# 14000/14000 [==============================] - 25s 2ms/step - loss: 0.0479 - accuracy: 0.9840
# Epoch 5/10
# 14000/14000 [==============================] - 25s 2ms/step - loss: 0.0375 - accuracy: 0.9881
# Epoch 6/10
# 14000/14000 [==============================] - 27s 2ms/step - loss: 0.0338 - accuracy: 0.9893
# Epoch 7/10
# 14000/14000 [==============================] - 29s 2ms/step - loss: 0.0324 - accuracy: 0.9896
# Epoch 8/10
# 14000/14000 [==============================] - 28s 2ms/step - loss: 0.0309 - accuracy: 0.9902
# Epoch 9/10
# 14000/14000 [==============================] - 26s 2ms/step - loss: 0.0295 - accuracy: 0.9907
# Epoch 10/10
# 14000/14000 [==============================] - 26s 2ms/step - loss: 0.0287 - accuracy: 0.9910
# Accuracy: 99.5
# Confusion matrix
#  [[19904    96]
#  [    8   992]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     20000
#            1       0.91      0.99      0.95      1000
#
#     accuracy                           1.00     21000
#    macro avg       0.96      0.99      0.97     21000
# weighted avg       1.00      1.00      1.00     21000
#
#
# F1_Score: 0.97
# Best Threshold=0.982605, F-Score=0.974
# PR AUC= 0.993
# Confusion matrix
#  [[19984    16]
#  [   37   963]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     20000
#            1       0.98      0.96      0.97      1000
#
#     accuracy                           1.00     21000
#    macro avg       0.99      0.98      0.99     21000
# weighted avg       1.00      1.00      1.00     21000
#
#
# Random Forest Classifier
#
# Accuracy: 99.32
# Confusion matrix
#  [[19901    99]
#  [   44   956]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     20000
#            1       0.91      0.96      0.93      1000
#
#     accuracy                           0.99     21000
#    macro avg       0.95      0.98      0.96     21000
# weighted avg       0.99      0.99      0.99     21000
#
#
# F1_Score: 0.96
# Best Threshold=0.741710, F-Score=0.947
# PR AUC= 0.976
# Confusion matrix
#  [[19971    29]
#  [   75   925]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     20000
#            1       0.97      0.93      0.95      1000
#
#     accuracy                           1.00     21000
#    macro avg       0.98      0.96      0.97     21000
# weighted avg       0.99      1.00      0.99     21000
#
#
# Train inter 10
# Fully connected layer
# Epoch 1/10
# 14000/14000 [==============================] - 24s 2ms/step - loss: 0.1602 - accuracy: 0.9449
# Epoch 2/10
# 14000/14000 [==============================] - 24s 2ms/step - loss: 0.0907 - accuracy: 0.9676
# Epoch 3/10
# 14000/14000 [==============================] - 25s 2ms/step - loss: 0.0720 - accuracy: 0.9758
# Epoch 4/10
# 14000/14000 [==============================] - 29s 2ms/step - loss: 0.0652 - accuracy: 0.9787
# Epoch 5/10
# 14000/14000 [==============================] - 26s 2ms/step - loss: 0.0609 - accuracy: 0.9803 0s - loss: 0.0610 - accura
# Epoch 6/10
# 14000/14000 [==============================] - 26s 2ms/step - loss: 0.0575 - accuracy: 0.9813
# Epoch 7/10
# 14000/14000 [==============================] - 24s 2ms/step - loss: 0.0546 - accuracy: 0.9826
# Epoch 8/10
# 14000/14000 [==============================] - 25s 2ms/step - loss: 0.0521 - accuracy: 0.9831
# Epoch 9/10
# 14000/14000 [==============================] - 24s 2ms/step - loss: 0.0497 - accuracy: 0.9841
# Epoch 10/10
# 14000/14000 [==============================] - 24s 2ms/step - loss: 0.0469 - accuracy: 0.9848
# Accuracy: 98.86
# Confusion matrix
#  [[19778   222]
#  [   17   983]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     20000
#            1       0.82      0.98      0.89      1000
#
#     accuracy                           0.99     21000
#    macro avg       0.91      0.99      0.94     21000
# weighted avg       0.99      0.99      0.99     21000
#
#
# F1_Score: 0.94
# Best Threshold=0.948167, F-Score=0.972
# PR AUC= 0.985
# Confusion matrix
#  [[19983    17]
#  [   40   960]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     20000
#            1       0.98      0.96      0.97      1000
#
#     accuracy                           1.00     21000
#    macro avg       0.99      0.98      0.98     21000
# weighted avg       1.00      1.00      1.00     21000
#
#
# Random Forest Classifier
#
# Accuracy: 99.3
# Confusion matrix
#  [[19896   104]
#  [   42   958]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     20000
#            1       0.90      0.96      0.93      1000
#
#     accuracy                           0.99     21000
#    macro avg       0.95      0.98      0.96     21000
# weighted avg       0.99      0.99      0.99     21000
#
#
# F1_Score: 0.96
# Best Threshold=0.746506, F-Score=0.950
# PR AUC= 0.975
# Confusion matrix
#  [[19974    26]
#  [   73   927]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     20000
#            1       0.97      0.93      0.95      1000
#
#     accuracy                           1.00     21000
#    macro avg       0.98      0.96      0.97     21000
# weighted avg       1.00      1.00      1.00     21000
#
#
# Train inter 10
# Fully connected layer
#
# Epoch 1/10
# 14000/14000 [==============================] - 24s 2ms/step - loss: 0.1689 - accuracy: 0.9376
# Epoch 2/10
# 14000/14000 [==============================] - 25s 2ms/step - loss: 0.0948 - accuracy: 0.9658
# Epoch 3/10
# 14000/14000 [==============================] - 32s 2ms/step - loss: 0.0723 - accuracy: 0.9746 0s - loss: 0.0726 - accuracy - ETA: 0s - loss:
# Epoch 4/10
# 14000/14000 [==============================] - 26s 2ms/step - loss: 0.0554 - accuracy: 0.9819
# Epoch 5/10
# 14000/14000 [==============================] - 31s 2ms/step - loss: 0.0455 - accuracy: 0.9855
# Epoch 6/10
# 14000/14000 [==============================] - 27s 2ms/step - loss: 0.0408 - accuracy: 0.9868
# Epoch 7/10
# 14000/14000 [==============================] - 27s 2ms/step - loss: 0.0381 - accuracy: 0.9879
# Epoch 8/10
# 14000/14000 [==============================] - 32s 2ms/step - loss: 0.0374 - accuracy: 0.9879
# Epoch 9/10
# 14000/14000 [==============================] - 25s 2ms/step - loss: 0.0364 - accuracy: 0.9885
# Epoch 10/10
# 14000/14000 [==============================] - 24s 2ms/step - loss: 0.0356 - accuracy: 0.9887
# Accuracy: 99.13
# Confusion matrix
#  [[19830   170]
#  [   13   987]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     20000
#            1       0.85      0.99      0.92      1000
#
#     accuracy                           0.99     21000
#    macro avg       0.93      0.99      0.96     21000
# weighted avg       0.99      0.99      0.99     21000
#
#
# F1_Score: 0.96
# Best Threshold=0.935487, F-Score=0.968
# PR AUC= 0.989
# Confusion matrix
#  [[19977    23]
#  [   42   958]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     20000
#            1       0.98      0.96      0.97      1000
#
#     accuracy                           1.00     21000
#    macro avg       0.99      0.98      0.98     21000
# weighted avg       1.00      1.00      1.00     21000
#
#
# Random Forest Classifier
#
# Accuracy: 99.29
# Confusion matrix
#  [[19894   106]
#  [   43   957]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     20000
#            1       0.90      0.96      0.93      1000
#
#     accuracy                           0.99     21000
#    macro avg       0.95      0.98      0.96     21000
# weighted avg       0.99      0.99      0.99     21000
#
#
# F1_Score: 0.96
# Best Threshold=0.766729, F-Score=0.949
# PR AUC= 0.974
# Confusion matrix
#  [[19976    24]
#  [   77   923]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     20000
#            1       0.97      0.92      0.95      1000
#
#     accuracy                           1.00     21000
#    macro avg       0.99      0.96      0.97     21000
# weighted avg       1.00      1.00      1.00     21000
#
#
# Train inter 10
# Fully connected layer
#
# Epoch 1/10
# 14000/14000 [==============================] - 25s 2ms/step - loss: 0.1533 - accuracy: 0.9473
# Epoch 2/10
# 14000/14000 [==============================] - 25s 2ms/step - loss: 0.0785 - accuracy: 0.9729
# Epoch 3/10
# 14000/14000 [==============================] - 25s 2ms/step - loss: 0.0606 - accuracy: 0.9804
# Epoch 4/10
# 14000/14000 [==============================] - 25s 2ms/step - loss: 0.0541 - accuracy: 0.9832
# Epoch 5/10
# 14000/14000 [==============================] - 24s 2ms/step - loss: 0.0502 - accuracy: 0.9844
# Epoch 6/10
# 14000/14000 [==============================] - 25s 2ms/step - loss: 0.0471 - accuracy: 0.9855
# Epoch 7/10
# 14000/14000 [==============================] - 25s 2ms/step - loss: 0.0452 - accuracy: 0.9861
# Epoch 8/10
# 14000/14000 [==============================] - 25s 2ms/step - loss: 0.0436 - accuracy: 0.9867
# Epoch 9/10
# 14000/14000 [==============================] - 26s 2ms/step - loss: 0.0427 - accuracy: 0.9866
# Epoch 10/10
# 14000/14000 [==============================] - 25s 2ms/step - loss: 0.0410 - accuracy: 0.9871
# Accuracy: 99.04
# Confusion matrix
#  [[19821   179]
#  [   23   977]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     20000
#            1       0.85      0.98      0.91      1000
#
#     accuracy                           0.99     21000
#    macro avg       0.92      0.98      0.95     21000
# weighted avg       0.99      0.99      0.99     21000
#
#
# F1_Score: 0.95
# Best Threshold=0.988109, F-Score=0.966
# PR AUC= 0.986
# Confusion matrix
#  [[19987    13]
#  [   55   945]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     20000
#            1       0.99      0.94      0.97      1000
#
#     accuracy                           1.00     21000
#    macro avg       0.99      0.97      0.98     21000
# weighted avg       1.00      1.00      1.00     21000
#
#
# Random Forest Classifier
#
# Accuracy: 99.31
# Confusion matrix
#  [[19899   101]
#  [   44   956]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     20000
#            1       0.90      0.96      0.93      1000
#
#     accuracy                           0.99     21000
#    macro avg       0.95      0.98      0.96     21000
# weighted avg       0.99      0.99      0.99     21000
#
#
# F1_Score: 0.96
# Best Threshold=0.772052, F-Score=0.949
# PR AUC= 0.974
# Confusion matrix
#  [[19976    24]
#  [   77   923]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     20000
#            1       0.97      0.92      0.95      1000
#
#     accuracy                           1.00     21000
#    macro avg       0.99      0.96      0.97     21000
# weighted avg       1.00      1.00      1.00     21000
#
#
# Train inter 10
# Fully connected layer
# Epoch 1/10
# 14000/14000 [==============================] - 27s 2ms/step - loss: 0.1538 - accuracy: 0.9462
# Epoch 2/10
# 14000/14000 [==============================] - 25s 2ms/step - loss: 0.0919 - accuracy: 0.9674
# Epoch 3/10
# 14000/14000 [==============================] - 25s 2ms/step - loss: 0.0766 - accuracy: 0.9752
# Epoch 4/10
# 14000/14000 [==============================] - 24s 2ms/step - loss: 0.0661 - accuracy: 0.9798
# Epoch 5/10
# 14000/14000 [==============================] - 29s 2ms/step - loss: 0.0580 - accuracy: 0.9821
# Epoch 6/10
# 14000/14000 [==============================] - 24s 2ms/step - loss: 0.0514 - accuracy: 0.9835
# Epoch 7/10
# 14000/14000 [==============================] - 25s 2ms/step - loss: 0.0472 - accuracy: 0.9849
# Epoch 8/10
# 14000/14000 [==============================] - 24s 2ms/step - loss: 0.0434 - accuracy: 0.9861
# Epoch 9/10
# 14000/14000 [==============================] - 25s 2ms/step - loss: 0.0387 - accuracy: 0.9880
# Epoch 10/10
# 14000/14000 [==============================] - 25s 2ms/step - loss: 0.0359 - accuracy: 0.9889 0s - loss: 0.036
# Accuracy: 99.27
# Confusion matrix
#  [[19860   140]
#  [   13   987]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     20000
#            1       0.88      0.99      0.93      1000
#
#     accuracy                           0.99     21000
#    macro avg       0.94      0.99      0.96     21000
# weighted avg       0.99      0.99      0.99     21000
#
#
# F1_Score: 0.96
# Best Threshold=0.942904, F-Score=0.976
# PR AUC= 0.989
# Confusion matrix
#  [[19989    11]
#  [   37   963]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     20000
#            1       0.99      0.96      0.98      1000
#
#     accuracy                           1.00     21000
#    macro avg       0.99      0.98      0.99     21000
# weighted avg       1.00      1.00      1.00     21000
#
#
# Random Forest Classifier
#
# Accuracy: 99.31
# Confusion matrix
#  [[19901    99]
#  [   45   955]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     20000
#            1       0.91      0.95      0.93      1000
#
#     accuracy                           0.99     21000
#    macro avg       0.95      0.98      0.96     21000
# weighted avg       0.99      0.99      0.99     21000
#
#
# F1_Score: 0.96
# Best Threshold=0.772022, F-Score=0.947
# PR AUC= 0.975
# Confusion matrix
#  [[19974    26]
#  [   78   922]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     20000
#            1       0.97      0.92      0.95      1000
#
#     accuracy                           1.00     21000
#    macro avg       0.98      0.96      0.97     21000
# weighted avg       0.99      1.00      0.99     21000
#
#
# Train inter 10
# Fully connected layer
#
# Epoch 1/10
# 14000/14000 [==============================] - 25s 2ms/step - loss: 0.1738 - accuracy: 0.9339
# Epoch 2/10
# 14000/14000 [==============================] - 25s 2ms/step - loss: 0.0861 - accuracy: 0.9701
# Epoch 3/10
# 14000/14000 [==============================] - 25s 2ms/step - loss: 0.0738 - accuracy: 0.9764
# Epoch 4/10
# 14000/14000 [==============================] - 27s 2ms/step - loss: 0.0632 - accuracy: 0.9810
# Epoch 5/10
# 14000/14000 [==============================] - 42s 3ms/step - loss: 0.0570 - accuracy: 0.9831
# Epoch 6/10
# 14000/14000 [==============================] - 44s 3ms/step - loss: 0.0540 - accuracy: 0.9836
# Epoch 7/10
# 14000/14000 [==============================] - 37s 3ms/step - loss: 0.0520 - accuracy: 0.9844
# Epoch 8/10
# 14000/14000 [==============================] - 24s 2ms/step - loss: 0.0501 - accuracy: 0.9850
# Epoch 9/10
# 14000/14000 [==============================] - 25s 2ms/step - loss: 0.0477 - accuracy: 0.9857
# Epoch 10/10
# 14000/14000 [==============================] - 28s 2ms/step - loss: 0.0455 - accuracy: 0.9863
# Accuracy: 98.72
# Confusion matrix
#  [[19746   254]
#  [   15   985]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     20000
#            1       0.79      0.98      0.88      1000
#
#     accuracy                           0.99     21000
#    macro avg       0.90      0.99      0.94     21000
# weighted avg       0.99      0.99      0.99     21000
#
#
# F1_Score: 0.94
# Best Threshold=0.971128, F-Score=0.972
# PR AUC= 0.988
# Confusion matrix
#  [[19974    26]
#  [   30   970]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     20000
#            1       0.97      0.97      0.97      1000
#
#     accuracy                           1.00     21000
#    macro avg       0.99      0.98      0.99     21000
# weighted avg       1.00      1.00      1.00     21000
#
#
# Random Forest Classifier
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-47-cd72404f9bfa> in <module>
#      29     for i in range(0,LOOP):
#      30         print("Train inter", LOOP)
# ---> 31         fcl_f1, rfc_f1 = train_evaluate(X_train4, y_train4, X_test4, y_test4)
#      32         fcl_f1_list.append(fcl_f1)
#      33         rfc_f1_list.append(rfc_f1)
#
# <ipython-input-41-e5e6a9038b16> in train_evaluate(X_train, y_train, X_test, y_test)
#      11     print("Random Forest Classifier \n")
#      12     rfc = RandomForestClassifier(**RFC_PARAMS)
# ---> 13     rfc.fit(X_train, y_train)
#      14
#      15     rfc_y_prob = rfc.predict_proba(X_test)[:,1]
#
# E:\Anaconda\envs\py37\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     456                     n_samples_bootstrap=n_samples_bootstrap,
#     457                 )
# --> 458                 for i, t in enumerate(trees)
#     459             )
#     460
#
# E:\Anaconda\envs\py37\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1044                 self._iterating = self._original_iterator is not None
#    1045
# -> 1046             while self.dispatch_one_batch(iterator):
#    1047                 pass
#    1048
#
# E:\Anaconda\envs\py37\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     859                 return False
#     860             else:
# --> 861                 self._dispatch(tasks)
#     862                 return True
#     863
#
# E:\Anaconda\envs\py37\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     777         with self._lock:
#     778             job_idx = len(self._jobs)
# --> 779             job = self._backend.apply_async(batch, callback=cb)
#     780             # A job can complete so quickly than its callback is
#     781             # called before we get here, causing self._jobs to
#
# E:\Anaconda\envs\py37\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# E:\Anaconda\envs\py37\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# E:\Anaconda\envs\py37\lib\site-packages\joblib\parallel.py in __call__(self)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     262             return [func(*args, **kwargs)
# --> 263                     for func, args, kwargs in self.items]
#     264
#     265     def __reduce__(self):
#
# E:\Anaconda\envs\py37\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     262             return [func(*args, **kwargs)
# --> 263                     for func, args, kwargs in self.items]
#     264
#     265     def __reduce__(self):
#
# E:\Anaconda\envs\py37\lib\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     207     def __call__(self, *args, **kwargs):
#     208         with config_context(**self.config):
# --> 209             return self.function(*args, **kwargs)
#     210
#     211
#
# E:\Anaconda\envs\py37\lib\site-packages\sklearn\ensemble\_forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     182             curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
#     183
# --> 184         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     185     else:
#     186         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# E:\Anaconda\envs\py37\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     940             sample_weight=sample_weight,
#     941             check_input=check_input,
# --> 942             X_idx_sorted=X_idx_sorted,
#     943         )
#     944         return self
#
# E:\Anaconda\envs\py37\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     418             )
#     419
# --> 420         builder.build(self.tree_, X, y, sample_weight)
#     421
#     422         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %%
print(f'> F1 Score FCL: {np.mean(fcl_f1_list)} (Độ lệch +- {np.std(fcl_f1_list)})')
print(f'> F1 Score RFC: {np.mean(rfc_f1_list)} (Độ lệch +- {np.std(rfc_f1_list)})')
# Out:
# > F1 Score FCL: 0.9614285714285715 (Độ lệch +- 0.012453996981544792)
# > F1 Score RFC: 0.96 (Độ lệch +- 0.0)
